# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Антон, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# Описание проекта
#
# * **Заказчик** - развлекательное приложения Procrastinate Pro+.
#
#
# * **Проблема:** Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
#
#
# * **Цель исследования:** Помочь компании выйти на прибыльность.
#
#
# * **Задачи исследовани:**
#     * изучить откуда приходят пользователи и какими устройствами они пользуются,
#     * изучить сколько стоит привлечение пользователей из различных рекламных каналов;
#     * изучить сколько денег приносит каждый клиент,
#     * изучить когда расходы на привлечение клиента окупаются,
#     * изучить какие факторы мешают привлечению клиентов.
#
#
# * **Данные:**
#     * Данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
#         * лог сервера с данными об их посещениях,
#         * выгрузка их покупок за этот период,
#         * рекламные расходы.

# %% [markdown]
# <a id="index"></a>
# **Содержание отчета:**
# 1. [Загрузка и подготовка данных](#load_and_open_data)
#     * [Загрузка библиотек и открытие датасетов](#load_and_open)
#     * [Обработка пропусков и дубликатов](#nans_duplicates)
#     * [Обработка типов данных](#data_types)
#     * [Выводы по подготовке данных](#summary_1)
# 2. [Функции для расчёта и анализа LTV, ROI, удержания и конверсии](#functions)
#     * [get_profiles() — для создания профилей пользователей](#get_profiles)
#     * [get_retention() — для подсчёта Retention Rate](#get_retention)
#     * [get_conversion() — для подсчёта конверсии](#get_conversion)
#     * [get_ltv() — для подсчёта LTV](#get_ltv)
#     * [filter_data() — для сглаживания данных](#filter_data)
#     * [plot_retention() — для построения графика Retention Rate](#plot_retention)
#     * [plot_conversion() — для построения графика конверсии](#plot_conversion)
#     * [plot_ltv_roi — для визуализации LTV и ROI](#plot_ltv_roi)
# 3. [Исследовательский анализ данных](#eda)
#     * [Профили пользователей](#users_profile)
#     * [Профили пользователей по странам](#countries)
#     * [Профили пользователей по устройствам](#devices)
#     * [Профили пользователей по каналам привлечения](#channels)
#     * [Выводы по исследовательскому анализу данных](#eda_summary)
# 4. [Маркетинг](#marketing)
#     * [Общие расходы на маркетинг](#marketing_cost)
#     * [Расходы на маркетинг по каналам](#channels_cost)
#     * [Динамика расходов на рекламу](#marketing_cost_history)
#     * [Стоимость привлечения пользователя](#cac)
#     * [Выводы по разделу Маркетинг](#marketing_summary)
# 5. [Оценка окупаемости рекламы](#roi)
#     * [Параметры исследования](#parameters)
#     * [Окупаемость рекламы (графики LTV и ROI, а также графики динамики LTV, CAC и ROI)](#ltv_cac_roi)
#     * [Конверсия пользователей и динамика её изменения](#conversions)
#     * [Удержание пользователей и динамика его изменения](#retention)
#     * [Окупаемость рекламы по устройствам](#roi_by_device)
#     * [Окупаемость рекламы по странам](#roi_by_region)
#     * [Окупаемость рекламы по каналам привлечения](#roi_by_channel)
#     * [Детальный анализ рекламы для США](#usa_analys)
#         * [LTV, ROI, CAC пользователей из США](#usa_roi)
#     * [Выводы по оценке окупаемости рекламы](#roi_summary)
# 6. [Общие выводы](#global_summary)

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример из 3 проекта:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <a id="load_and_open_data"></a>
# ### Загрузите данные и подготовьте их к анализу

# %% [markdown]
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %% [markdown]
# <a id="load_and_open"></a>
# #### Загрузка библиотек и открытие датасетов

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns
import warnings

# Отключаем предупреждения
warnings.filterwarnings('ignore')

# %%
visits, orders, costs = (
    pd.read_csv('/datasets/visits_info_short.csv'),
    pd.read_csv('/datasets/orders_info_short.csv'),
    pd.read_csv('/datasets/costs_info_short.csv')
)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Для подгрузки данных можно использовать конструкцию `try-except`, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей.
#
# Подробнее о конструкции по ссылке:
#
# https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html
#
# Либо же можно использовать стандартную библиотеку os:
#
# https://pythonworld.ru/moduli/modul-os.html
#
#
# Несколько интересных статей кейсы использования конструкции:
#
# https://www.programiz.com/python-programming/exception-handling
#
# https://towardsdatascience.com/do-not-abuse-try-except-in-python-d9b8ee59e23b
#
# https://www.techbeamers.com/use-try-except-python/
#
# Как вариант в try можно указать корректные пути (в нашем случае глобальные) в except - некорректные (локальные). Можно также специфицровать тип ошибки, FileNotFoundError или задать кастомный тип ошибки (FilePathError, например)
#
# Она полезна, если ты работаешь локально, а потом подгружаешь проект на платформу. Конструкция позволит не падать коду и локально, и на сервере ЯП, так как если не сработает один блок с путями, сработает другой.
#
# Ну и вообще, в целом полезно про эту констуркцию знать, она универсальна и может быть использована в разных задачах.

# %%
# Проверим таблицу посещений
display(visits.head())
print(visits.shape[0])
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
# 309901

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# В единственной или последней строке ячейки кода Юпитера, метод print() не обязателен, в отличии от тренажера

# %%
# Проверим таблицу покупок
display(orders.head())
print(orders.shape[0])
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# 40212

# %%
# Проверим таблицу затрат на рекламу
display(costs.head())
print(costs.shape[0])
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# 1800

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="nans_duplicates"></a>
# #### Обработка пропусков и дубликатов

# %%
# Проверим пропуски в таблице посещений
visits.isna().sum()
# Out:
# User Id          0
# Region           0
# Device           0
# Channel          0
# Session Start    0
# Session End      0
# dtype: int64

# %%
# Проверим пропуски в таблице покупок
orders.isna().sum()
# Out:
# User Id     0
# Event Dt    0
# Revenue     0
# dtype: int64

# %%
# Проверим пропуски в таблице расходов на рекламу
costs.isna().sum()
# Out:
# dt         0
# Channel    0
# costs      0
# dtype: int64

# %% [markdown]
# Пропусков в датасете не обнаружено

# %%
# Дубликаты в таблице посещений
visits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов не обнаружено

# %%
# Проверим возможные неявные дубликаты (разный регистр, лишние пробелы и т.д.)
visits['Region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits['Device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits['Channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %% [markdown]
# Неявных дубликатов также не обнаружено

# %%
# Дубликаты в таблице покупок
orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов не обнаружено, категориальные признаки отсутствуют

# %%
# Дубликаты в таблице расходов на рекламу
costs.duplicated().sum()
# Out:
# 0

# %%
# Проверим возможные неявные дубликаты (разный регистр, лишние пробелы и т.д.)
costs['Channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="data_types"></a>
# #### Обработка типов данных

# %%
# Проверим типы данных в таблице посещений
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
# Приведем поля начала и окончания сессии к типу datetime
visits['Session Start'] = pd.to_datetime(visits['Session Start']).dt.date
visits['Session End'] = pd.to_datetime(visits['Session End']).dt.date

# %%
# Проверим типы данных в таблице покупок
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
# Приведем поле даты покупки к типу datetime
orders['Event Dt'] = pd.to_datetime(orders['Event Dt']).dt.date

# %%
# Проверим типы данных в таблице покупок
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
# Приведем поле даты проведения рекламных расходов к типу datetime
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="summary_1"></a>
# #### Выводы по подготовке данных

# %% [markdown]
# -  В таблице посещений (visits) содержится 309901 записей, в таблице покупок (orders) 40212 записей, в таблице расходов на рекламу (costs) 1800 записей
#
# - Пропусков в таблицах не обнаружено, явные и неявные дубликаты отсутствуют
#
# - В датасетах проведено преобразование над полями дат, приведены к типу datetime
#
# [📘К содержанию](#index)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Хорошо, основные действия по предобработке сделаны, здорово, что ты не забыли проверить данные на наличие дубликатов.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# * чтобы переименовать колонки, можно также использовать метод `rename()`
#
#
# * если мы только привели преобразование в строчные символы и заменили пробел на знак `_`, то мы можем использовать такой подход:
#
# `visits.columns = visits.columns.str.lower().str.replace(' ', '_')`. Является простым и читаемым способом преобразования. Этот подход особенно полезен для быстрого и последовательного применения преобразований к строкам.
#
# * также интересным является подход с использованием list comprehensions:
#
# `visits.columns = [x.lower().replace(' ', '_') for x in visits.columns.values]`
#
#
# Данный подход использует list comprehensions, что может быть быстрее на больших датасетах благодаря оптимизации Python для list comprehensions. Этот метод также предоставляет гибкость в добавлении дополнительных операций или условий при необходимости. Однако, он может быть менее очевидным для тех, кто только начинает работать с Python. Этот подход "интересен" тем, что он показывает, как одна и та же задача может быть решена разными способами, и некоторые из них могут быть более эффективными или гибкими в зависимости от конкретного контекста.
#
#
# ---
#
# * на стадии загрузки и подготовки данных к исследовательскому анализу, советую посмотреть на данные более детально, чтобы избежать невынужденных ошибок в дальнейшем. Чем большем мы знаем о данных - тем более корректны и обоснованы выглядят наши выводы. Такие проверки много времени не занимают, но зато мы можем лучше контролировать данные и их анализ. Например, мы можем:
#     - проверить временной интервал на соответствие условию проекта, а также на возможные ошибки (например, проверить случаи, когда окончание сессии было раньше, и так далее);
#     - для численных данных посмотреть на их статистические показатели и проверить их на наличие каких-то ошибок или аномалий (например, нули или отрицательные значения там, где они не должны быть).

# %% [markdown]
# <a id="functions"></a>
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.

# %% [markdown]
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# <a id="get_profiles"></a>
# #### get_profiles() — для создания профилей пользователей

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['User Id', 'Session Start'])
        .groupby('User Id')
        .agg(
            {
                'Session Start': 'first',
                'Channel': 'first',
                'Device': 'first',
                'Region': 'first',
            }
        )
        .rename(columns={'Session Start': 'first_ts'})
        .reset_index()
    )
    profiles['first_ts'] = pd.to_datetime(profiles['first_ts'])

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].values.astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['User Id'].isin(orders['User Id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'Channel'])
        .agg({'User Id': 'nunique'})
        .rename(columns={'User Id': 'unique_users'})
        .reset_index()
    )
    
    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'Channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'Channel', 'acquisition_cost']],
        on=['dt', 'Channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# Проверим работу функции
profiles = get_profiles(visits, orders, costs)
print(profiles.head(5))
# Out:
#     User Id   first_ts     Channel  Device         Region          dt  \
# 0    599326 2019-05-07    FaceBoom     Mac  United States  2019-05-07
# 1   4919697 2019-07-09    FaceBoom  iPhone  United States  2019-07-09
# 2   6085896 2019-10-01     organic  iPhone         France  2019-10-01
# 3  22593348 2019-08-22  AdNonSense      PC        Germany  2019-08-22
# 4  31989216 2019-10-02     YRabbit  iPhone  United States  2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True          1.088172
# 1 2019-07-01  False          1.107237
# 2 2019-10-01  False          0.000000
# 3 2019-08-01  False          0.988235
# 4 2019-10-01  False          0.230769

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="get_retention"></a>
# #### get_retention() — для подсчёта Retention Rate

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['User Id', 'Session Start']], on='User Id', how='left'
    )
    
    result_raw['first_ts'] = pd.to_datetime(result_raw['first_ts'])
    result_raw['Session Start'] = pd.to_datetime(result_raw['Session Start'])
    
    result_raw['lifetime'] = (result_raw['Session Start'] - result_raw['first_ts']).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='User Id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'User Id': 'nunique'})
            .rename(columns={'User Id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# Проверим работу функции
observation_date = datetime(2019, 10, 1).date()
horizon_days = 10

result_raw, result_grouped, result_in_time = get_retention(
    profiles,
    visits,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
)

print(result_raw.shape,result_grouped.shape,result_in_time.shape)
# Out:
# (250164, 11) (2, 11) (290, 11)

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="get_conversion"></a>
# #### get_conversion() — для подсчёта конверсии

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        orders.sort_values(by=['User Id', 'Event Dt'])
        .groupby('User Id')
        .agg({'Event Dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['User Id', 'Event Dt']], on='User Id', how='left'
    )
    
    result_raw['Event Dt'] = pd.to_datetime(result_raw['Event Dt'])
    result_raw['first_ts'] = pd.to_datetime(result_raw['first_ts'])

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['Event Dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='User Id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'User Id': 'nunique'})
            .rename(columns={'User Id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# Проверим работу функции
result_raw, result_grouped, result_in_time = get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
)
print(result_raw.shape,result_grouped.shape,result_in_time.shape)
# Out:
# (116737, 12) (1, 11) (145, 11)

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="get_ltv"></a>
# #### get_ltv() — для подсчёта LTV

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        orders[['User Id', 'Event Dt', 'Revenue']], on='User Id', how='left'
    )
    
    result_raw['Event Dt'] = pd.to_datetime(result_raw['Event Dt'])
    result_raw['first_ts'] = pd.to_datetime(result_raw['first_ts'])
    
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['Event Dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='Revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'User Id': 'nunique'})
            .rename(columns={'User Id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['User Id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
# Проверим работу функции
result_raw, result_grouped, result_in_time, roi_grouped, roi_in_time = get_ltv(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
)

print(result_raw.shape,result_grouped.shape,result_in_time.shape,roi_grouped.shape, roi_in_time.shape)
# Out:
# (144949, 13) (1, 11) (145, 11) (1, 12) (145, 12)

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="filter_data"></a>
# #### filter_data() — для сглаживания данных

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="plot_retention"></a>
# #### plot_retention() — для построения графика Retention Rate

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="plot_conversion"></a>
# #### plot_conversion() — для построения графика конверсии

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="plot_ltv_roi"></a>
# #### plot_ltv_roi — для визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, все необходимые функции были заданы, можно приступать к расчета и анализу👀

# %% [markdown]
# <a id="eda"></a>
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %% [markdown]
# <a id="users_profile"></a>
# #### Профили пользователей

# %%
# С помощью функции get_profiles() соберем профили пользователей
profiles = get_profiles(visits, orders, costs)

# %%
# Посмотрим на полученные данные
profiles
# Out:
#              User Id   first_ts       Channel  Device         Region  \
# 0             599326 2019-05-07      FaceBoom     Mac  United States
# 1            4919697 2019-07-09      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01       organic  iPhone         France
# 3           22593348 2019-08-22    AdNonSense      PC        Germany
# 4           31989216 2019-10-02       YRabbit  iPhone  United States
# ...              ...        ...           ...     ...            ...
# 150003  999956196527 2019-09-28        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21       organic      PC             UK
# 150005  999976332130 2019-07-23        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18       organic  iPhone  United States
#
#                 dt      month  payer  acquisition_cost
# 0       2019-05-07 2019-05-01   True          1.088172
# ...

# %%
# Найдем минимальную и максимальную дату привлечения
first_ts_min = profiles['first_ts'].min()
first_ts_max = profiles['first_ts'].max()

print(f'Минимальная дата:{first_ts_min}\nМаксимальная дата:{first_ts_max}')
# Out:
# Минимальная дата:2019-05-01 00:00:00
# Максимальная дата:2019-10-27 00:00:00

# %% [markdown]
# Собрана информация о 150008 пользователей. Самая ранняя дата привлечения - 1 мая 2019, самая поздняя - 27 октября 2019 г.

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Неплохо бы проверить даты на соответствие ТЗ,  иначе не совсем понятно, зачем мы смотрели на эти даты (например, соответствую ли даты ТЗ или нет).
# </div>

# %% [markdown]
# <a id="countries"></a>
# #### Профили пользователей по странам

# %%
# При помощи сводной таблицы посчитаем общее количество пользователей, число платящих
# и найдем долю платящих пользователей

# Соберем сводную таблицу по странам
payers_by_country = profiles.pivot_table(index='Region',
                                         values='payer',
                                         aggfunc=['count','sum']).reset_index()

# Переименуем столбцы
payers_by_country.columns=['Region','num_users','num_payers']

# Посчитаем долю платящих пользователей
payers_by_country['payers_share'] = payers_by_country['num_payers'] / payers_by_country['num_users']

# Посмотрим полученные данные
payers_by_country
# Out:
#           Region  num_users  num_payers  payers_share
# 0         France      17450         663      0.037994
# 1        Germany      14981         616      0.041119
# 2             UK      17575         700      0.039829
# 3  United States     100002        6902      0.069019

# %% [markdown]
# Больше всего пользователей из **США** - **более 100 тыс. человек**, меньше всего из **Германии (чуть менее 15 000)**, количество пользователей из **Франции** и **Великобритании** примерно одинаковы и составляет около **17500 пользователей.**
#
# Наибольшая доля платящих пользователей приходится на **США** - почти **7%.** В остальных странах доля плятящих пользователей не превышает **4.1%.**

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="devices"></a>
# #### Профили пользователей по устройствам

# %%
# Аналогично со странами построим сводную таблицу по устройствам

# Соберем сводную таблицу по устройствам
payers_by_devices = profiles.pivot_table(index='Device',
                                         values='payer',
                                         aggfunc=['count','sum']).reset_index()

# Переименуем столбцы
payers_by_devices.columns=['Device','num_users','num_payers']

# Посчитаем долю платящих пользователей
payers_by_devices['payers_share'] = payers_by_devices['num_payers'] / payers_by_devices['num_users']

# Посмотрим полученные данные
payers_by_devices
# Out:
#     Device  num_users  num_payers  payers_share
# 0  Android      35032        2050      0.058518
# 1      Mac      30042        1912      0.063644
# 2       PC      30455        1537      0.050468
# 3   iPhone      54479        3382      0.062079

# %% [markdown]
# * С существенным отрывом среди устройств лидирует **iPhone - 54.5 тыс.** пользователей.
#
# * На втором месте пользователи с устройствами **Android - 35 тыс.**
#
# * Количество пользователей **PC** и **Mac** почти равно и составляет чуть более **30 тыс.**
#
#
# * Реже всего платящие пользователи встречаются среди владельцев PC - **5%**
# * **Чаще всего платят** пользователи **Mac** и **iPhone** - **6.2-6.3%**
# * Платящих пользователей среди владельцев Android чуть меньше чем среди фанатов Apple - **5.9%**

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="channels"></a>
# #### Профили пользователей по каналам привлечения

# %% [markdown]
# Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
# Аналогично построим сводную таблицу по каналам привлечения

# Соберем сводную таблицу по каналам
payers_by_channels = profiles.pivot_table(index='Channel',
                                          values='payer',
                                          aggfunc=['count','sum']).reset_index()

# Переименуем столбцы
payers_by_channels.columns=['Channel','num_users','num_payers']

# Посчитаем долю платящих пользователей
payers_by_channels['payers_share'] = payers_by_channels['num_payers'] / payers_by_channels['num_users']

# Посмотрим полученные данные
payers_by_channels
# Out:
#                Channel  num_users  num_payers  payers_share
# 0           AdNonSense       3880         440      0.113402
# 1             FaceBoom      29144        3557      0.122049
# 2              LeapBob       8553         262      0.030633
# 3         MediaTornado       4364         156      0.035747
# 4   OppleCreativeMedia       8605         233      0.027077
# 5       RocketSuperAds       4448         352      0.079137
# 6               TipTop      19561        1878      0.096007
# 7       WahooNetBanner       8553         453      0.052964
# 8              YRabbit       4312         165      0.038265
# 9       lambdaMediaAds       2149         225      0.104700
# 10             organic      56439        1160      0.020553

# %%
# Таблица получилась большая, построим барплот для данных по количеству пользователей по каналам привлечения
sns.set_theme(style="whitegrid")
ax = sns.barplot(x='num_users',
                 y='Channel',
                 data=payers_by_channels.sort_values(by='num_users', ascending=False))
plt.title('Кол-во привлеченных пользователей по каналам')
plt.xlabel('Количество')
plt.ylabel('Канал');

# %% [markdown]
# * Больше всего пользователей пришли **органическим способом**, т.е. сами - более **56 тыс.**
#
# * Два следующих крупных канала - **FaceBoom(29 тыс.)** и **TipTop(19.5 тыс.)**
#
# * Остальные каналы привлекли менее 10 тыс. пользователей.

# %%
# Построим барплот для доли платящих пользователей по каналам привлечения
sns.set_theme(style="whitegrid")
ax = sns.barplot(x='payers_share',
                 y='Channel',
                 data=payers_by_channels.sort_values(by='payers_share', ascending=False))
plt.title('Доля платящих пользователей по каналам')
plt.xlabel('Доля')
plt.ylabel('Канал');

# %% [markdown]
# * Меньше всего платящих пользователей оказалоссь среди пришедших самостоятельно - **2%**
#
# * Больше всего доля платящих пользователей (**10-12%**) - у привлеченных каналами FaceBoom, AdNoneSense, LambdaMediaAds.

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="eda_summary"></a>
# #### Выводы по исследовательскому анализу данных

# %% [markdown]
# * Собрана информация о 150008 пользователей. Самая ранняя дата привлечения - **1 мая 2019**, самая поздняя - **27 октября 2019 г.**
#
#
# * **Пользователи по странам:**
#     * Больше всего пользователей из **США** - **более 100 тыс. человек**, меньше всего из **Германии (чуть менее 15 000)**, количество пользователей из **Франции** и **Великобритании** примерно одинаковы и составляет около **17500 пользователей.**
#
#     * Наибольшая доля платящих пользователей приходится на **США** - почти **7%.** В остальных странах доля плятящих пользователей не превышает **4.1%.**
#
#
# * **Пользователи по устройствам:**
#     * С существенным отрывом среди устройств лидирует **iPhone - 54.5 тыс.** пользователей.
#
#     * На втором месте пользователи с устройствами **Android - 35 тыс.**
#
#     * Количество пользователей **PC** и **Mac** почти равно и составляет чуть более **30 тыс.**
#
#     * Реже всего платящие пользователи встречаются среди владельцев PC - **5%**
#     * **Чаще всего платят** пользователи **Mac** и **iPhone** - **6.2-6.3%**
#     * Платящих пользователей среди владельцев Android чуть меньше чем среди фанатов Apple - **5.9%**
#
#
# * **Пользователи по каналам привлечения:**
#     * Больше всего пользователей пришли **органическим способом**, т.е. сами - более **56 тыс.**
#
#     * Два следующих крупных канала - **FaceBoom(29 тыс.)** и **TipTop(19.5 тыс.)**
#
#     * Остальные каналы привлекли менее 10 тыс. пользователей.
#
#     * Меньше всего платящих пользователей оказалоссь среди пришедших самостоятельно - **2%**
#
#     * Больше всего доля платящих пользователей (**10-12%**) - у привлеченных каналами FaceBoom, AdNoneSense, LambdaMediaAds.
#
# [📘К содержанию](#index)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# В целом в данном разделе был проведен хороший анализ данных - мы посмотрели на базовые значения конверсии пользователей в покупатели по регионам, устройствам и каналу привлечения, определили основной рынок. Получается, что больше всего приходит пользователей из США и они лучше других конвертируется. При этом большая часть пользователей заходит с мобильных устройств, это тоже стоит отметить. Также, мы можем сказать, что наибольшую конверсию имеют пользователи, которые пользуются Mac, а затем следуют пользователи iPhone, т.е. мы можем сказать, что в целом пользователи Apple имеют лучшую конверсию в покупателей. Возможно, тут есть плюсы ApplePay.

# %% [markdown]
# <a id="marketing"></a>
# ###  Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# <a id="marketing_cost"></a>
# #### Общие расходы на маркетинг

# %%
#Просмотрим таблицу с данными о расходах на рекламу
costs.head(3)
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8

# %%
# Найдем общую сумму расходов на маркетинг
costs['costs'].sum()
# Out:
# 105497.30000000002

# %% [markdown]
# Общая сумма расходов на маркетинг - **105497** долларов

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Лучше округлить до 1-2 знаков, после запятой
# </div>

# %% [markdown]
# <a id="channels_cost"></a>
# #### Расходы на маркетинг по каналам

# %%
# Построим сводную таблицу расходов на рекламу в разрезе каналов
ad_costs_by_channels = costs.pivot_table(index='Channel', 
                                         values='costs', 
                                         aggfunc='sum').reset_index()
ad_costs_by_channels.colums=['Channel', 'cost']
ad_costs_by_channels
# Out:
#               Channel     costs
# 0          AdNonSense   3911.25
# 1            FaceBoom  32445.60
# 2             LeapBob   1797.60
# 3        MediaTornado    954.48
# 4  OppleCreativeMedia   2151.25
# 5      RocketSuperAds   1833.00
# 6              TipTop  54751.30
# 7      WahooNetBanner   5151.00
# 8             YRabbit    944.22
# 9      lambdaMediaAds   1557.60

# %%
# Построим пайчарт для структуры расходов на рекламу по каналам
plt.pie(ad_costs_by_channels['costs'],
        labels=ad_costs_by_channels['Channel'],
        autopct='%.0f%%');

# %% [markdown]
# Из-за большого количества каналов график выглядит плохо, но на нем ясно видно, что **83%** всех расходов на рекламу пришлись на два канала - **TipTop (52%)** и **FaceBoom (31%)**.

# %%
# Построим барплот для расходов на рекламу по каналам
sns.set_theme(style="whitegrid")
ax = sns.barplot(x='costs',
                 y='Channel',
                 data=ad_costs_by_channels.sort_values(by='costs', ascending=False))
plt.title('Расходы на рекламу по каналам')
plt.xlabel('Расходы на рекламу')
plt.ylabel('Канал');

# %% [markdown]
# * По всем каналам кроме TipTop и FaceBoom расходы не превышают **5.2 тыс. долл.**
#
# * Расходы на **TipTop - около 55 тыс.долл**, на **FaceBoom - 32.4 тыс. долл.**

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="marketing_cost_history"></a>
# #### Динамика расходов на рекламу

# %%
# Добавим в датасет Costs номера недель и месяца
costs['dt'] = pd.to_datetime(costs['dt'])
costs['week'] = costs['dt'].dt.isocalendar().week
costs['month'] = costs['dt'].dt.month

# %%
# Сгруппируем данные по неделям и каналам
costs_by_weeks = costs.pivot_table(index=['Channel', 'week'],
                                   values='costs',
                                   aggfunc='sum').reset_index()
costs_by_weeks.columns=['Channel','Week','Costs']

# %%
# Построим понедельную динамику расходов на рекламу по каналам
plt.figure(figsize=(15, 10))
sns.lineplot(x="Week", y="Costs",
             hue="Channel",
             data=costs_by_weeks.sort_values(by='Costs', ascending=False))

plt.title('Понедельная динамика расходов на рекламу')
plt.xlabel('Неделя')
plt.ylabel('Расходы');

# %% [markdown]
# * На понедельном графике также виден разрыв в уровнях расходов на рекламу между TipTop, FaceBoom и остальными каналами.
# * Недельные расходы на TipTop все время растут, так с 500 долл/неделю расходы увеличились до 3250 долл, на пике достигали 4000 долл/неделю.
# * Недельные расходы на FaceBoom более стабильны и колеблются в коридоре 1000-1500 долл/неделя, прослеживается тренд на увеличение расходов.
# * По остальным каналам расходы стабильны и редко превышают 250 долл/неделю.

# %%
# Сгруппируем данные по месяцам и каналам
costs_by_month = costs.pivot_table(index=['Channel', 'month'],
                                   values='costs',
                                   aggfunc='sum').reset_index()
costs_by_month.columns=['Channel','Month','Costs']

# %%
# Построим помесячную динамику расходов на рекламу по каналам
plt.figure(figsize=(15, 10))
sns.lineplot(x="Month", y="Costs",
             hue="Channel",
             data=costs_by_month.sort_values(by='Costs', ascending=False))

plt.title('Понедельная динамика расходов на рекламу')
plt.xlabel('Неделя')
plt.ylabel('Расходы');

# %% [markdown]
# * Ежемесячные расходы на TipTop вросли с 3000 долл. в мае до 12000 долл. в октябре, максимум расходов пришелся на сентябрь и составил около 13000 долл.
# * Ежемесячно на FaceBoom расходуется 5-6 тыс. долл.
# * На остальные каналы расходуется не более 1000 долл/мес.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличный и наглядный график 👍
#
# Здорово, когда он подписан. Так быстрее понять о чем идёт речь на нём.
#
# </div>

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="cac"></a>
# #### Стоимость привлечения пользователя

# %%
# Сделаем срез для нахождения стоимости привлечения пользователей (откинем органический канал)
cac_profiles = profiles.query('Channel!="organic"')[['Channel','payer','acquisition_cost']]
cac_profiles
# Out:
#              Channel  payer  acquisition_cost
# 0           FaceBoom   True          1.088172
# 1           FaceBoom  False          1.107237
# 3         AdNonSense  False          0.988235
# 4            YRabbit  False          0.230769
# 7         AdNonSense   True          1.008000
# ...              ...    ...               ...
# 149999        TipTop  False          1.900000
# 150001      FaceBoom  False          1.117838
# 150003        TipTop  False          3.500000
# 150005        TipTop  False          2.600000
# 150006  MediaTornado  False          0.205714
#
# [93569 rows x 3 columns]

# %%
# Сделаем сводную таблицу по стоимости привлечения в разрезе каналов
cac_by_channels = cac_profiles.pivot_table(index='Channel',
                                           values='acquisition_cost',
                                           aggfunc='mean').reset_index()
cac_by_channels.columns = ['Channel', 'cac']
cac_by_channels
# Out:
#               Channel       cac
# 0          AdNonSense  1.008054
# 1            FaceBoom  1.113286
# 2             LeapBob  0.210172
# 3        MediaTornado  0.218717
# 4  OppleCreativeMedia  0.250000
# 5      RocketSuperAds  0.412095
# 6              TipTop  2.799003
# 7      WahooNetBanner  0.602245
# 8             YRabbit  0.218975
# 9      lambdaMediaAds  0.724802

# %%
# Визуализируем полученную информацию

sns.set_theme(style="whitegrid")
ax = sns.barplot(x='cac',
                 y='Channel',
                 data=cac_by_channels.sort_values(by='cac', ascending=False))
plt.title('Стоимость привлечения по каналам')
plt.xlabel('Стоимость привлечения пользователя')
plt.ylabel('Канал');

# %% [markdown]
# * Cамая высокая стоимость привлечения пользователя у TipTop - почти $2.8
#
# * Далее идет группа каналов со стоимостью привлечения от 0.6 до 1.1 долл. - FaceBoom, AdNonSense, LambadaMediaAds, WahooNetBanner
#
# * У оставшихся каналов стоимость привлечения не превышает 0.25-0.5 доллара.

# %%
# Попробуем в таблицу со стоимостью привлечения добавить разрез платящих пользователей
cac_payers_by_channels = cac_profiles.pivot_table(index='Channel',
                                                  columns='payer',
                                                  values='acquisition_cost',
                                                  aggfunc='mean').reset_index()
cac_payers_by_channels.columns = ['Channel', 'not payers', 'payers']
cac_payers_by_channels
# Out:
#               Channel  not payers    payers
# 0          AdNonSense    1.007662  1.011119
# 1            FaceBoom    1.113292  1.113243
# 2             LeapBob    0.210165  0.210378
# 3        MediaTornado    0.218766  0.217389
# 4  OppleCreativeMedia    0.249987  0.250456
# 5      RocketSuperAds    0.411546  0.418493
# 6              TipTop    2.800388  2.785961
# 7      WahooNetBanner    0.602338  0.600576
# 8             YRabbit    0.219279  0.211338
# 9      lambdaMediaAds    0.723572  0.735322

# %% [markdown]
# Существенной разницы между стоимость привлечения платящих и не платящих пользователей нет.

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="marketing_summary"></a>
# #### Выводы по разделу маркетинг

# %% [markdown]
# * Общая сумма расходов на маркетинг - **105.5 тыс.** долларов
#
#
# * **Расходы по каналам привлечения:**
#     * **83%** всех расходов на рекламу пришлись на два канала - **TipTop (52%)** и **FaceBoom (31%)**
#     * По всем каналам кроме TipTop и FaceBoom расходы не превышают **5.2 тыс. долл.**
#     * Расходы на **TipTop - около 55 тыс.долл**, на **FaceBoom - 32.4 тыс. долл.**
#
# * **Недельные расходы на рекламу:**
#     * На понедельном графике также виден разрыв в уровнях расходов на рекламу между TipTop, FaceBoom и остальными каналами.
#     * Недельные расходы на TipTop все время растут, так с 500 долл/неделю расходы увеличились до 3250 долл, на пике достигали 4000 долл/неделю.
#     * Недельные расходы на FaceBoom более стабильны и колеблются в коридоре 1000-1500 долл/неделя, прослеживается тренд на увеличение расходов.
#     * По остальным каналам расходы стабильны и редко превышают 250 долл/неделю.
# ![image.png](attachment:image.png)
#
# * **Ежемесячные расходы на рекламу:**
#     * Ежемесячные расходы на TipTop вросли с 3000 долл. в мае до 12000 долл. в октябре, максимум расходов пришелся на сентябрь и составил около 13000 долл.
#     * Ежемесячно на FaceBoom расходуется 5-6 тыс. долл.
#     * На остальные каналы расходуется не более 1000 долл/мес.
# ![image-2.png](attachment:image-2.png)
#
# * **Стоимость привлечения пользователей по каналам:**
#     * Cамая высокая стоимость привлечения пользователя у TipTop - почти $2.8
#     * Далее идет группа каналов со стоимостью привлечения от 0.6 до 1.1 долл. - FaceBoom, AdNonSense, LambadaMediaAds, WahooNetBanner
#     * У оставшихся каналов стоимость привлечения не превышает 0.25-0.5 доллара
#     * Существенной разницы между стоимость привлечения платящих и не платящих пользователей нет.
#
# [📘К содержанию](#index)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Наиболее дорогостоящим каналом привлечения пользователей является TipTop, однако количество и доля платящих пользователей, приходящих с этого источника, не так высоки. Это можно объяснить молодой аудиторией TipTop'a и, соответственно, не очень высокой их платежеспособностью.
#
# </div>

# %% [markdown]
# <a id="roi"></a>
# ###   Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# <a id="parameters"></a>
# #### Параметры исследования

# %%
# Зададим дату наблюдения
observation_date = datetime(2019, 11, 1).date()

# Зададим горизонт анализа
horizon_days = 14

# %%
# Отбросим органических пользователей (т.к. стоимость их привлечения нулевая, а также они редко становятся платящими)
non_organic = profiles.query('Channel!="organic"')

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Совершенно верно, поскольку мы за них ничего не платим,  а нам нужно изучить именно окупаемость рекламы.
# </div>

# %% [markdown]
# <a id="ltv_cac_roi"></a>
# #### Окупаемость рекламы (графики LTV и ROI, а также графики динамики LTV, CAC и ROI)

# %%
# Найдем LTV, динамику LTV, ROI и динамику ROI
ltv_raw,ltv,ltv_in_time, roi, roi_in_time = (
get_ltv(
    non_organic,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
    )
)

# %%
# Построим графики LTV, динамики LTV, ROI и динамики ROI
plot_ltv_roi(ltv,ltv_in_time,
             roi,
             roi_in_time,
             horizon_days,
             window=7)

# %% [markdown]
# Из полученных графиков можно сделать следующие выводы:
# * Реклама убыточна, ROI на 14й день - 80%
# * В динамике ROI был выше уровня окупаемости для привлеченных с мая по июнь, для привлеченных в последующие периоды ROI все время снижается и достигает 60% в конце октября.
# * CAC растет, значит наблюдается увеличение рекламного бюджета.
# * LTV стабилен, варьируется в корирдоре 0.8-1

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Логика анализа верная, согласен с выводом. Наблюдаем, что динамика ROI за лайфтайм падает. При относительно стабильной динамике LTV, динамика САС растёт с мая по конец октября. Эту закономерность мы наблюдаем в динамике ROI, что при сильном увеличении САС, в равной степени падает динамика ROI пользователей.
# </div>

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="conversions"></a>
# #### Конверсия пользователей и динамика её изменения

# %%
# Получим данные по конверсиям
conversion_raw, conversion, conversion_history = (
get_conversion(
    non_organic,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
    )
)

# %%
# Построим графики по конверсиям
plot_conversion(conversion, 
                conversion_history, 
                horizon_days, 
                window=7)

# %% [markdown]
# Наблюдения:
# * Конверсия на 14й день достигает 8%
# * Наименьшая конверсия была у привлеченных в середине мая 2019 г.
# * Максимальная конверсия была у привлеченных в середине июня - почти 9.8%
# * Для привлеченных в последующие периоды конверсия колеблется в коридоре 7-8.8%
#
# Обобщенная конверсия дает мало информации, построим графики в доступных разрезах

# %%
# Построим графики по конверсиям в разрезе устройств
conversion_raw_device, conversion_device, conversion_history_device = (
get_conversion(
    non_organic,
    orders,
    observation_date,
    horizon_days,
    dimensions=['Device'],
    ignore_horizon=False,
    )
)

plot_conversion(conversion_device, 
                conversion_history_device, 
                horizon_days, 
                window=14)

# %% [markdown]
# Конверсии по устройствам на 14й день
# * Самая низкая конверсия у пользователей PC - 6.5%
# * Самые высокие конверсии у пользователей c устройствами Apple - 8.5%
# * Чуть ниже конверсия у пользователей с Android - 8%
# * В динамике конверсия пользователей c PC оказывалась хуже всего для привлеченных с июня по октябрь 2019г.

# %%
# Построим графики по конверсиям в разрезе каналов привлечения
conversion_raw_channel, conversion_channel, conversion_history_channel = (
get_conversion(
    non_organic,
    orders,
    observation_date,
    horizon_days,
    dimensions=['Channel'],
    ignore_horizon=False,
    )
)

plot_conversion(conversion_channel, 
                conversion_history_channel, 
                horizon_days, 
                window=21)

# %% [markdown]
# Конверсия по каналам:
# * Лучшая конверсия у пользователей привлеченных FaceBoom - 12%
# * Далее идут пользователи из AdNonSence и LambadaMadiaAds - чуть более 10%
# * Самы низкие показатели конверсии у пользователей из YaRabbit, MediaTornado, LeapBob, OppleCreativeMedia - от 2 до 4%
# * В помесячном разрезе конверсии по каналам в целом стабильны, у LambadaMadiaAds и AdNonSence наблюдается высокая волатильность от месяца к месяцу.

# %%
# Построим графики по конверсиям в разрезе регионов
conversion_raw_region, conversion_region, conversion_history_region = (
get_conversion(
    non_organic,
    orders,
    observation_date,
    horizon_days,
    dimensions=['Region'],
    ignore_horizon=False,
    )
)

plot_conversion(conversion_region, 
                conversion_history_region, 
                horizon_days, 
                window=14)

# %% [markdown]
# Конверсии по регионам:
# * На графике хорошо виден отрыв уровня конверсий пользователей из США (более 9.5%) от конверсионности пользователей из других регионов, которая очень близка и составляет около 5%.
# * На графике с помесячной динамикой также виден стабильно высокий уровень конверсий пользователей из США.
# * Конверсия пользователей из Франции, Великобритании и Германии существенно снизилась с конца мая (7-8%) и больше не поднималась выше 7%.

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="retention"></a>
# #### Удержание пользователей и динамика его изменения

# %% [markdown]
# То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.

# %%
# Получим данные по удержанию
retention_raw, retention, retention_in_time = get_retention(
    non_organic,
    visits,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
    )

# %%
# Построим графики по удержанию
plot_retention(retention,
               retention_in_time,
               horizon_days,
               window=7)

# %% [markdown]
# Графики выглядят корректно.
#
# * Удержание платящих пользователей на 14й день - около 12%.
# * Среди платящих пользователей, привлеченных в середине июня была просадка до 6%, в целом показатель удержания стабилен.
#
#
# Обобщенные данные малоинформативны, построим графики удержания в разрезе устройств и каналов привличения

# %%
# Построим графики удержания по устройствам
retention_raw_device, retention_device, retention_in_time_device = get_retention(
    non_organic,
    visits,
    observation_date,
    horizon_days,
    dimensions=['Device'],
    ignore_horizon=False,
    )

plot_retention(retention_device,
               retention_in_time_device,
               horizon_days,
               window=14)

# %% [markdown]
# Удержание по устройствам:
# * Линия удержания платящих пользователей PC лежит заметно выше линий пользователей других устройств, на 14 день удержание составляет порядка 15%.
# * Линии удержания платящих пользователей всех остальных устройств находятся очень близко, практически сливаются, удержание на 14й день по ним составляет около 12%.
# * У привлеченных в середине мая платящих пользователей PC удержание находилось на уровне 30%, после этого произошло существенное снижение для пользователей привлеченных с июня, после июня удержание пользователей PC варьируется в коридоре 12-20%, в динамике также видно что показатель удержания пользователей PC находится выше пользователей других устройств, в болшинстве периодов с июня по октябрь.

# %%
# Построим графики удержания по каналам
retention_raw_channel, retention_channel, retention_in_time_channel = get_retention(
    non_organic,
    visits,
    observation_date,
    horizon_days,
    dimensions=['Channel'],
    ignore_horizon=False,
    )

plot_retention(retention_channel,
               retention_in_time_channel,
               horizon_days,
               window=14)

# %% [markdown]
# Удержание пользователей по каналам привлечения:
# * Хуже всего удержания у привлеченных из AdNoneSense и FaceBoom - меньше 5%. Эти же каналы попали в лидеры по показателю конверсии.
# * Удержание остальных каналов близки и находятся на уровне 15-25%. На графике хорошо виден разрыв всех остальных каналов и AdNoneSense с FaceBoom.
# * Непрерывный график удержания по месяцам есть только у TipTop и FaceBoom, FaceBoom - стабильно низкий показатель, значительно лучше удержание у TipTop, но с середины сентября удержание по данному каналу снижается.

# %%
# Построим графики удержания по регионам
retention_raw_region, retention_region, retention_in_time_region = get_retention(
    non_organic,
    visits,
    observation_date,
    horizon_days,
    dimensions=['Region'],
    ignore_horizon=False,
    )

plot_retention(retention_region,
               retention_in_time_region,
               horizon_days,
               window=14)

# %% [markdown]
# Удержание пользователей по регионам:
# * Хуже всего показатель удержания у пользователей из США (10%), кривые удержания остальных стран близки и варьируются на 14й день на уровне 15-20%
# * В помесячной разбивке кривая удержания непрерывна только у США, она же стабильна и на всем проимежутке находится в районе 10%. Кривые удержания других стран сильно колеблются в диапозоне 10-35% и прерываются.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, анализ конверсии и удержания корректен

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="roi_by_device"></a>
# #### Окупаемость рекламы по устройствам

# %%
# Аналогично п.5.2 найдем LTV, динамику LTV, ROI и динамику ROI в разрезе устройств пользователей
ltv_raw_device,ltv_device,ltv_in_time_device, roi_device, roi_in_time_device = (
get_ltv(
    non_organic,
    orders,
    observation_date,
    horizon_days,
    dimensions=['Device'],
    ignore_horizon=False,
    )
)
# Построим графики LTV, динамики LTV, ROI и динамики ROI
plot_ltv_roi(ltv_device,
             ltv_in_time_device,
             roi_device,
             roi_in_time_device,
             horizon_days,
             window=21)

# %% [markdown]
# Наблюдения по окупаемости рекламы в разрезе устройств пользователей:
# * Реклама окупается только для пользователей PC, при этом LTV пользователей PC заметно ниже других платформ.
# * ROI рекламы для пользователей Android на 14й день достигает около 90%.
# * ROI рекламы для пользователей устройств Apple (iPhone и Mac практически идентичны) около 70%.
# * LTV в помесячной динамике в целом стабильна, для PC наблюдается заметное снижение LTV в конце июля и середине октября.
# * По графику динамики ROI видно что окупаемость рекламы по всем платформам перешла в отрицательную зону с сентября.
# * По устройствам PC также заметен отрицательный тренд, остальные платформы на всем периоде наблюдения были убыточны.
# * Стоимость привлечения по всем устройствам растет.
# * Быстрее всего рост наблюдается по устройствам Apple.
# * У PC наиболее плавный рост стоимости привлечения.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С окупаемостью проблемы по всем устройствам кроме PC. Это значит, что у нас, по крайней мере, нет технических проблем, влияющих на монетизацию;
# </div>

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="roi_by_region"></a>
# #### Окупаемость рекламы по странам

# %%
# Найдем LTV, динамику LTV, ROI и динамику ROI в разрезе стран
ltv_raw_region,ltv_region,ltv_in_time_region, roi_region, roi_in_time_region = (
get_ltv(
    non_organic,
    orders,
    observation_date,
    horizon_days,
    dimensions=['Region'],
    ignore_horizon=False,
    )
)
# Построим графики LTV, динамики LTV, ROI и динамики ROI
plot_ltv_roi(ltv_region,
             ltv_in_time_region,
             roi_region,
             roi_in_time_region,
             horizon_days,
             window=21)

# %% [markdown]
# На данных графиках сразу стала очевидна проблема с рекламой в США.
#
# Окупаемость рекламы по странам:
# * Сымый высокий показатель LTV у США - при этом идинственная страна для которой реклама убыточна - также США
# * В остальных странах реклама окупается, ROI около 150%
# * Динамика LTV США стабильна и выше других стран
# * Динамика LTV Франции, Германии и Великобритании также стабилбна
# * По динамике ROI также видем, что на всем рассматриваемом промежутке реклама США убыточна, реклама в других странах прибыльна
# * Стоимость привлечения по всем странам за исключением США снизилась в середине июня и оставалась стабильной до конца рассматриваемого периода.
# * Стоимость привлечения для США растет на всем рассматриваемом промежутке времени, так стоимость с 0.8  в мае выросла почти до 1.8 в конце октября. С учетом убыточности рекламы и постоянным ростом стоимости привлечения при высоком качестве пользователей США ситуация носит аномальный характер.
#
# Суммируя выводы - необходимо подробней разобраться с рекламой в США.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Все верно. Нужно разбираться детальнее с рекламой в США, тем более, что это наш основной рынок.

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# <a id="roi_by_channel"></a>
# #### Окупаемость рекламы по каналам привличения

# %%
# Найдем LTV, динамику LTV, ROI и динамику ROI в разрезе каналов привлечения
ltv_raw_channel,ltv_channel,ltv_in_time_channel, roi_channel, roi_in_time_channel = (
get_ltv(
    non_organic,
    orders,
    observation_date,
    horizon_days,
    dimensions=['Channel'],
    ignore_horizon=False,
    )
)
# Построим графики LTV, динамики LTV, ROI и динамики ROI
plot_ltv_roi(ltv_channel,
             ltv_in_time_channel,
             roi_channel,
             roi_in_time_channel,
             horizon_days,
             window=21)

# %% [markdown]
# Окупаемость рекламы по каналам привлечения:
# * Самые качественные пользователи у привлеченных LambadaMediaAds и TipTop (LTV=1.5-1.75)
# * Реклама у TipTop, FaceBoom и AdNoneSense не окупается, все остальные каналы рентабельны.
# * Динамика LTV очень волантильна у LambadaMediaAds, остальные источники относительно стабильны.
# * По динамике ROI видим, что реклама FaceBoom и TipTop стабильно убыточна на всем рассматриваемом промежутке, реклама AdNoneSense балансирует на уровне 0.
# * На пике ROI для канала YRabbit достигала 600%
# * Динамика ROI остальных каналов относительно стабильна, реклама окупалась на всем рассмматриваемом промежутке времени.
# * По стоимости привлечения видим аномалию с ростом у TipTop, остальные каналы стабильны.
#
# Суммировав анализ по трем срезам:
# * В разрезе устройств не окупается реклама для всех кроме PC. Стоимость привлечения особенно явно растет для устройств Apple
# * В разрезе стран - единственная убыточная - США
# * В разрезе каналов привличения - реклама TipTop, FaceBoom и AdNoneSense не окупается. Аномальный рост стоимости привлечения у TipTop
#
# Теперь когда известен набор проблемных параметров - посмотрим подробнее данные по убыточной стране - США.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Да, действительно, есть проблемы с каналом TipTop, видим значительный рост затрат на привлечение.
# </div>

# %% [markdown]
# [📘К содержанию](#index)

# %% [markdown]
# Ответьте на такие вопросы:
# Окупается ли реклама, направленная на привлечение пользователей в целом?
# Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# Чем могут быть вызваны проблемы окупаемости?

# %% [markdown]
# <a id="usa_analys"></a>
# #### Детальный анализ рекламы для США

# %%
# Сделаем срез, оставив в неорганических пользователях только пользователей из США
usa_profiles = non_organic.query('Region=="United States"')

# %% [markdown]
# <a id="usa_roi"></a>
# ##### LTV, ROI, CAC пользователей из США

# %%
# Найдем LTV, динамику LTV, ROI и динамику ROI в разрезе устройств пользователей
ltv_raw_device,ltv_device_usa,ltv_in_time_device_usa, roi_device_usa, roi_in_time_device_usa = (
get_ltv(
    usa_profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=['Device'],
    ignore_horizon=False,
    )
)
# Построим графики LTV, динамики LTV, ROI и динамики ROI
plot_ltv_roi(ltv_device_usa,
             ltv_in_time_device_usa,
             roi_device_usa,
             roi_in_time_device_usa,
             horizon_days,
             window=21)

# %% [markdown]
# Окупаемость рекламы по устройствам в США:
# * LTV стабильна
# * Реклама не окупается для всех устройств
# * ROI c июня стабильно в отрицательной зоне для всех устройств, с отрицательным трендом
# * Стоимость привличения растет быстрыми темпами для всех устройств.
#
# Дело явно не в устройствах пользователей

# %%
# Найдем LTV, динамику LTV, ROI и динамику ROI в разрезе каналов привлечения
ltv_raw_channel_usa,ltv_channel_usa,ltv_in_time_channel_usa, roi_channel_usa, roi_in_time_channel_usa = (
get_ltv(
    usa_profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=['Channel'],
    ignore_horizon=False,
    )
)
# Построим графики LTV, динамики LTV, ROI и динамики ROI
plot_ltv_roi(ltv_channel_usa,
             ltv_in_time_channel_usa,
             roi_channel_usa,
             roi_in_time_channel_usa,
             horizon_days,
             window=21)

# %% [markdown]
# * Самые качественные и дорогие пользователи приходят по каналу TipTop
# * Реклама у TipTop и FaceBoom убыточна. При этом известно что на долю этих двух компаний приходится 83% всего рекламного бюджета.
# * ROI остальных каналов превышает 200%
# * Самая эффективная реклама у YaRabbit - ROI около 250%, близко идет MediTornado. Пиковый ROI у YaRabbit достигал 600% (середина июля)
# * Также у YaRabbit одна из самых низких стоимостей привлечения.
# * Видим постоянный рост стоимости привлечения для TipTop, ранее смотрели рост рекламных расходов по данному каналу в течении всего года и он значительно превышает затраты на все другие каналы.

# %% [markdown]
# Выводы:
# * Возможная причина убыточности рекламы - недеверсифицированный бюджет с перекосом в сторону двух не самых эффективных каналов.
# * Каналы с лучшими показателями ROI получают меньшие бюджеты.
# * Также проблема с тем что США тянет всю рекламу в убыток связана с наибольшей долей пользователей в этой стране, большей долей бюджета на рекламу и неэффективным его распределением
#
# Предварительные рекомендации:
# * Перераспредлить бюджет на рекламу в пользу источников с высокими показателями качества (LTV) и высокими показателями ROI, снизить финансирование неэффективных каналов, даже если данные каналы приводят более качественных пользователей.
# * Решение о распределении рекламных бюджетов должно обязательно приниматься комплексно и обязательно исходить в том числе из показателя ROI а не только LTV, retention, conversion.
# * Конкретно для США рекомендуется обратить внимание на YaRabbit, RocketSuperAds, MediaTornado - источники приводят качественных дешевых пользователей с высоким ROI.
#
#
# [📘К содержанию](#index)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# А вот это...очень грамотный шаг. Молодец, что рассмотрели эти данные дополнительно. У тебя получился очень сильный проект

# %% [markdown]
# <a id="roi_summary"></a>
# #### Выводы по оценке окупаемости рекламы

# %% [markdown]
# * **Окупаемость рекламы:**
#     * Реклама убыточна, ROI на 14й день - 80%
#     * В динамике ROI был выше уровня окупаемости для привлеченных с мая по июнь, для привлеченных в последующие периоды ROI все время снижается и достигает 60% в конце октября.
#     * CAC растет, значит наблюдается увеличение рекламного бюджета.
#     * LTV стабилен, варьируется в корирдоре 0.8-1
#
#
# * **Конверсия пользователей:**
#     * Конверсия на 14й день достигает 8%
#     * Наименьшая конверсия была у привлеченных в середине мая 2019 г.
#     * Максимальная конверсия была у привлеченных в середине июня - почти 9.8%
#     * Для привлеченных в последующие периоды конверсия колеблется в коридоре 7-8.8%
#     * Конверсии по устройствам:
#         * Самая низкая конверсия у пользователей PC - 6.5%
#         * Самые высокие конверсии у пользователей c устройствами Apple - 8.5%
#         * Чуть ниже конверсия у пользователей с Android - 8%
#         * В динамике конверсия пользователей c PC оказывалась хуже всего для привлеченных с июня по октябрь 2019г.
#     * Конверсии по каналам привлечения:
#         * Лучшая конверсия у пользователей привлеченных FaceBoom - 12%
#         * Далее идут пользователи из AdNonSence и LambadaMadiaAds - чуть более 10%
#         * Самы низкие показатели конверсии у пользователей из YaRabbit, MediaTornado, LeapBob, OppleCreativeMedia - от 2 до 4%
#         * В помесячном разрезе конверсии по каналам в целом стабильны, у LambadaMadiaAds и AdNonSence наблюдается высокая волатильность от месяца к месяцу.
#      * Конверсия по регионам:
#         * На графике хорошо виден отрыв уровня конверсий пользователей из США (более 9.5%) от конверсионности пользователей из других регионов, которая очень близка и составляет около 5%.
#         * На графике с помесячной динамикой также виден стабильно высокий уровень конверсий пользователей из США.
#         * Конверсия пользователей из Франции, Великобритании и Германии существенно снизилась с конца мая (7-8%) и больше не поднималась выше 7%.
#
#
# * **Удержание пользователей:**
#     * Удержание платящих пользователей на 14й день - около 12%.
#     * Среди платящих пользователей, привлеченных в середине июня была просадка до 6%, в целом показатель удержания стабилен.
#     * Удержание по устройствам:
#         * Линия удержания платящих пользователей PC лежит заметно выше линий пользователей других устройств, на 14 день удержание составляет порядка 15%.
#         * Линии удержания платящих пользователей всех остальных устройств находятся очень близко, практически сливаются, удержание на 14й день по ним составляет около 12%.
#         * У привлеченных в середине мая платящих пользователей PC удержание находилось на уровне 30%, после этого произошло существенное снижение для пользователей привлеченных с июня, после июня удержание пользователей PC варьируется в коридоре 12-20%, в динамике также видно что показатель удержания пользователей PC находится выше пользователей других устройств, в болшинстве периодов с июня по октябрь.
#     * Удержание по каналам привлечения:
#         * Хуже всего удержания у привлеченных из AdNoneSense и FaceBoom - меньше 5%. Эти же каналы попали в лидеры по показателю конверсии.
#         * Удержание остальных каналов близки и находятся на уровне 15-25%. На графике хорошо виден разрыв всех остальных каналов и AdNoneSense с FaceBoom.
#         * Непрерывный график удержания по месяцам есть только у TipTop и FaceBoom, FaceBoom - стабильно низкий показатель, значительно лучше удержание у TipTop, но с середины сентября удержание по данному каналу снижается.
#     * Удержание по регионам:
#         * Хуже всего показатель удержания у пользователей из США (10%), кривые удержания остальных стран близки и варьируются на 14й день на уровне 15-20%
#         * В помесячной разбивке кривая удержания непрерывна только у США, она же стабильна и на всем проимежутке находится в районе 10%. Кривые удержания других стран сильно колеблются в диапозоне 10-35% и прерываются.
#
# * Окупаемость рекламы в разрезе устройств пользователей:
#     * Реклама окупается только для пользователей PC, при этом LTV пользователей PC заметно ниже других платформ.
#     * ROI рекламы для пользователей Android на 14й день достигает около 90%.
#     * ROI рекламы для пользователей устройств Apple (iPhone и Mac практически идентичны) около 70%.
#     * LTV в помесячной динамике в целом стабильна, для PC наблюдается заметное снижение LTV в конце июля и середине октября.
#     * По графику динамики ROI видно что окупаемость рекламы по всем платформам перешла в отрицательную зону с сентября.
#     * По устройствам PC также заметен отрицательный тренд, остальные платформы на всем периоде наблюдения были убыточны.
#     * Стоимость привлечения по всем устройствам растет.
#     * Быстрее всего рост наблюдается по устройствам Apple.
#     * У PC наиболее плавный рост стоимости привлечения.
#
#
# * **Окупаемость рекламы по странам:**
# На графиках сразу стала очевидна проблема с рекламой в США.
#
#     * Сымый высокий показатель LTV у США - при этом идинственная страна для которой реклама убыточна - также США
#     * В остальных странах реклама окупается, ROI около 150%
#     * Динамика LTV США стабильна и выше других стран
#     * Динамика LTV Франции, Германии и Великобритании также стабилбна
#     * По динамике ROI также видем, что на всем рассматриваемом промежутке реклама США убыточна, реклама в других странах прибыльна
#     * Стоимость привлечения по всем странам за исключением США снизилась в середине июня и оставалась стабильной до конца рассматриваемого периода.
#     * Стоимость привлечения для США растет на всем рассматриваемом промежутке времени, так стоимость с 0.8  в мае выросла почти до 1.8 в конце октября. С учетом убыточности рекламы и постоянным ростом стоимости привлечения при высоком качестве пользователей США ситуация носит аномальный характер.
#
# Суммируя выводы - необходимо подробней разобраться с рекламой в США.
#
# * **Окупаемость рекламы по каналам привлечения:**
#     * Самые качественные пользователи у привлеченных LambadaMediaAds и TipTop (LTV=1.5-1.75)
#     * Реклама у TipTop, FaceBoom и AdNoneSense не окупается, все остальные каналы рентабельны.
#     * Динамика LTV очень волантильна у LambadaMediaAds, остальные источники относительно стабильны.
#     * По динамике ROI видим, что реклама FaceBoom и TipTop стабильно убыточна на всем рассматриваемом промежутке, реклама AdNoneSense балансирует на уровне 0.
#     * На пике ROI для канала YRabbit достигала 600%
#     * Динамика ROI остальных каналов относительно стабильна, реклама окупалась на всем рассмматриваемом промежутке времени.
#     * По стоимости привлечения видим аномалию с ростом у TipTop, остальные каналы стабильны.
#
# * Суммировав анализ по трем срезам:
#     * В разрезе устройств не окупается реклама для всех кроме PC. Стоимость привлечения особенно явно растет для устройств Apple
#     * В разрезе стран - единственная убыточная - США
#     * В разрезе каналов привличения - реклама TipTop, FaceBoom и AdNoneSense не окупается. Аномальный рост стоимости привлечения у TipTop
#
#
# * **LTV, ROI, CAC пользователей из США**
#     * Окупаемость рекламы по устройствам в США:
#         * LTV стабильна
#         * Реклама не окупается для всех устройств
#         * ROI c июня стабильно в отрицательной зоне для всех устройств, с отрицательным трендом
#         * Стоимость привличения растет быстрыми темпами для всех устройств.
#         * Убытки явно не связаны с устройствами пользователей
#     * Окупаемость рекламы по каналам привлечения в США:
#         * Самые качественные и дорогие пользователи приходят по каналу TipTop
#         * Реклама у TipTop и FaceBoom убыточна. При этом известно что на долю этих двух компаний приходится 83% всего рекламного бюджета.
#         * ROI остальных каналов превышает 200%
#         * Самая эффективная реклама у YaRabbit - ROI около 250%, близко идет MediTornado. Пиковый ROI у YaRabbit достигал 600% (середина июля)
#         * Также у YaRabbit одна из самых низких стоимостей привлечения.
#         * Видим постоянный рост стоимости привлечения для TipTop, ранее смотрели рост рекламных расходов по данному каналу в течении всего года и он значительно превышает затраты на все другие каналы.
#
#
# [📘К содержанию](#index)

# %% [markdown]
# <a id="global_summary"></a>
# ###   Напишите выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# Причины убыточности компании:
# * Недеверсифицированный бюджет с перекосом в сторону двух не самых эффективных каналов.
# * Каналы с лучшими показателями ROI получают меньшие бюджеты.
# * США - самая большая страна по количеству пользователей и рекламному бюджету, поэтому использование неэффективных рекламных источников тянет вниз показатели всей компании в целом.
#
#
# Рекомендации:
# * Выяснить причины направление большей доли бюджета на источники TipTop и FaceBoom (какой был расчет, исходя из каких предпосылок принималось такое решение)
# * Разобраться детальней в причинах убыточности каналов TipTop и FaceBoom, запросить дополнительную доступную информацию.
# * Перераспредлить бюджет на рекламу в пользу источников с высокими показателями качества (LTV) и высокими показателями ROI, снизить финансирование неэффективных каналов, даже если данные каналы приводят более качественных пользователей.
# * Решение о распределении рекламных бюджетов должно обязательно приниматься комплексно и обязательно исходить в том числе из показателя ROI а не только LTV, retention и conversion.
# * **Для США рекомендуется обратить внимание на YaRabbit, RocketSuperAds, MediaTornado - источники приводят качественных дешевых пользователей с высоким ROI.**
# * Проводить регулярный мониторинг эффективности маркетинга
# * Своевременно проводить необходимые корректировки.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Я бы не рекомендовал вкладываться в канал `Yrabbit`. Почему я так думаю: да, канал сейчас окупается, потому что там низкий CAC. Фактически мы сейчас сильно много не платим за новых клиентов (CAC = 0,21) . И уже на этих клиентах (которые обошлись нам недорого) мы сможем спрогнозировать будущую картину. Они имеют низкую конвертируемость и сильно падающее удержание на последних днях горизонта. Т.е. можно сделать вывод, что им не интересно наше приложение. Возможно, это просто не наша аудитория. Они не заинтересованы в нашем приложении

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №1__
#
# С моей стороны критических замечаний нету. Если возникнут вопросы по ревью, то их можно передать через куратора.
#
# ---
#
#
#
# Всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличный материал про продуктовую аналитику Дмитрия Животворева.
#
# https://www.youtube.com/watch?v=Vy_rq-x9QEo
